# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv("binaaz_train.csv")
df_test = pd.read_csv("binaaz_test.csv")
df_train.head()
# Out:
#    _id                                              title   price  \
# 0    6    Satılır 3 otaqlı yeni tikili 135 m², Gənclik m.  300000
# 1   22  Satılır 3 otaqlı yeni tikili 132.5 m², Nəriman...  153000
# 2   72      Satılır 2 otaqlı yeni tikili 115 m², Bayıl q.  171300
# 3   76     Satılır 2 otaqlı yeni tikili 43 m², Masazır q.   44500
# 4   86  Satılır 2 otaqlı yeni tikili 65 m², Memar Əcəm...   89900
#
#   price_currency         poster       poster_type  \
# 0            AZN        Mubariz  vasitəçi (agent)
# 1            AZN  Самир Ахмедов  vasitəçi (agent)
# 2            AZN         Fikrət  vasitəçi (agent)
# 3            AZN          QASIM  vasitəçi (agent)
# 4            AZN     Heydər bəy  vasitəçi (agent)
#
#                                Ünvan  \
# 0   Bakı şəhəri, Bakıxanov  küçəsi
# 1      Bakı şəhəri, ул.Табриза 21-23
# 2      Bakı şəhəri, Q.Abbasov küçəsi
# 3      Bakı şəhəri, İstiqlaliyyət 14
# 4        Bakı şəhəri, Mir Cəlal küç.
#
# ...

# %%
df_train["Sahə"] = df_train["Sahə"].apply(lambda x: float(x.split(" ")[0]))
df_test["Sahə"] = df_test["Sahə"].apply(lambda x: float(x.split(" ")[0]))

# %%
df_train["exact_mertebe"] = df_train["Mərtəbə"].apply(lambda x: int(x.split(" / ")[0]))
df_test["exact_mertebe"] = df_test["Mərtəbə"].apply(lambda x: int(x.split(" / ")[0]))

# %%
df_train["relative_mertebe"] = df_train["Mərtəbə"].apply(lambda x: int(x.split(" / ")[0]) / int(x.split(" / ")[1]))
df_test["relative_mertebe"] = df_test["Mərtəbə"].apply(lambda x: int(x.split(" / ")[0]) / int(x.split(" / ")[1]))

# %%
df_train['Kupça'] = df_train['Kupça'].map({'var': 1, 'yoxdur': 0})
df_train['İpoteka'] = df_train['İpoteka'].map({'var': 1, 'yoxdur': 0})
df_test['Kupça'] = df_test['Kupça'].map({'var': 1, 'yoxdur': 0})
df_test['İpoteka'] = df_test['İpoteka'].map({'var': 1, 'yoxdur': 0})

# %%
seherler = pd.get_dummies(df_train["seher"])
df_train = df_train.drop('seher',axis = 1)
df_train = df_train.join(seherler)

# %%
seherler_test = pd.get_dummies(df_test["seher"])
df_test = df_test.drop('seher',axis = 1)
df_test = df_test.join(seherler_test)

# %%
def is_urgent(description):
    urg=['tecili', 'təcili', 'срочно',"cox","çox"]
    
    for word in str(description).split():
        if word.lower() in urg:
            return 1
    for word in str(description).split('.'):
        if word.lower() in urg:
            return 1
    for word in str(description).split(','):
        if word.lower() in urg:
            return 1
    return 0
df_train['is_urgent'] = df_train.apply(lambda row: is_urgent(row.description), axis=1)
df_test['is_urgent'] = df_test.apply(lambda row: is_urgent(row.description), axis=1)

# %%
def is_urgent(description):
    urg=['metro', 'm.', 'м.','метро','metronun',"metrosuna","metroya","m/s","metrosunun"]
    
    for word in str(description).split():
        if word.lower() in urg:
            return 1
    for word in str(description).split('.'):
        if word.lower() in urg:
            return 1
    for word in str(description).split(','):
        if word.lower() in urg:
            return 1
    return 0
df_train['metro'] = df_train.apply(lambda row: is_urgent(row.title), axis=1)
df_test['metro'] = df_test.apply(lambda row: is_urgent(row.title), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def is_urgent(description):
    urg=['merkez', 'mərkəz', 'mərkəzinə',"mərkəzində",'mərkəzinin','mərkəzi','центр',"merkezi"]
    
    for word in str(description).split():
        if word.lower() in urg:
            return 1
    for word in str(description).split('.'):
        if word.lower() in urg:
            return 1
    for word in str(description).split(','):
        if word.lower() in urg:
            return 1
    return 0
df_train['merkez'] = df_train.apply(lambda row: is_urgent(row.description), axis=1)
df_test['merkez'] = df_test.apply(lambda row: is_urgent(row.description), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def is_urgent(description):
    urg=["temirli","təmirli","ремонт","отремонтированный"]
    
    for word in str(description).split():
        if word.lower() in urg:
            return 1
    for word in str(description).split('.'):
        if word.lower() in urg:
            return 1
    for word in str(description).split(','):
        if word.lower() in urg:
            return 1
    return 0
df_train['temir'] = df_train.apply(lambda row: is_urgent(row.description), axis=1)
df_test['temir'] = df_test.apply(lambda row: is_urgent(row.description), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def is_urgent(description):
    urg=["kompleksi","kompleks","комплекс","kompleksin","kompleksinde","kompleksində","kompleksinin"]
    
    for word in str(description).split():
        if word.lower() in urg:
            return 1
    for word in str(description).split('.'):
        if word.lower() in urg:
            return 1
    for word in str(description).split(','):
        if word.lower() in urg:
            return 1
    return 0
df_train['kompleks'] = df_train.apply(lambda row: is_urgent(row.description), axis=1)
df_test['kompleks'] = df_test.apply(lambda row: is_urgent(row.description), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def is_urgent(description):
    urg=['qazli', 'qazlı','qaz','газ',"свет","вода"]
    
    for word in str(description).split():
        if word.lower() in urg:
            return 1
    for word in str(description).split('.'):
        if word.lower() in urg:
            return 1
    for word in str(description).split(','):
        if word.lower() in urg:
            return 1
    return 0
df_train['qaz'] = df_train.apply(lambda row: is_urgent(row.description), axis=1)
df_test['qaz'] = df_test.apply(lambda row: is_urgent(row.description), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def is_urgent(description):
    urg=['deniz', 'denize','dəniz','dənizə',"море","приморье",]
    
    for word in str(description).split():
        if word.lower() in urg:
            return 1
    for word in str(description).split('.'):
        if word.lower() in urg:
            return 1
    for word in str(description).split(','):
        if word.lower() in urg:
            return 1
    return 0
df_train['deniz'] = df_train.apply(lambda row: is_urgent(row.description), axis=1)
df_test['deniz'] = df_test.apply(lambda row: is_urgent(row.description), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def is_urgent(description):
    urg=['ucuz', 'дешево','дешевле','дешевый',"asagi","aşağı"]
    
    for word in str(description).split():
        if word.lower() in urg:
            return 1
    for word in str(description).split('.'):
        if word.lower() in urg:
            return 1
    for word in str(description).split(','):
        if word.lower() in urg:
            return 1
    return 0
df_train['ucuz'] = df_train.apply(lambda row: is_urgent(row.description), axis=1)
df_test['ucuz'] = df_test.apply(lambda row: is_urgent(row.description), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def is_urgent(description):
    urg=["park","parki","parkı","parkın","парк","парка","парком","parkdi","parkdı"]
    
    for word in str(description).split():
        if word.lower() in urg:
            return 1
    for word in str(description).split('.'):
        if word.lower() in urg:
            return 1
    for word in str(description).split(','):
        if word.lower() in urg:
            return 1
    return 0
df_train['park'] = df_train.apply(lambda row: is_urgent(row.description), axis=1)
df_test['park'] = df_test.apply(lambda row: is_urgent(row.description), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def is_urgent(description):
    urg=["mekteblere","mektebe","mekteb","universitet","universitetin","universiteti","universitete","universitetine","universitetinə","məktəbə","məktəbin","məktəbinin","liseyinin"]
    
    for word in str(description).split():
        if word.lower() in urg:
            return 1
    for word in str(description).split('.'):
        if word.lower() in urg:
            return 1
    for word in str(description).split(','):
        if word.lower() in urg:
            return 1
    return 0
df_train['uni'] = df_train.apply(lambda row: is_urgent(row.description), axis=1)
df_test['uni'] = df_test.apply(lambda row: is_urgent(row.description), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import h3
iceriseher = (40.366131,49.831605)
sahil = (40.371309, 49.844516)
_28_may=(40.380087,49.848637)
genclik=(40.400640,49.851941)
neriman_nerimanov=(40.403156,49.870734)
ulduz=(40.41540,49.891461)
koroglu=(40.421961,49.916977)
qara_qarayev=(40.418031,49.932189)
neftciler=(40.410407,49.943227)
bakmil=(40.414405,49.879480)
xalqlar=(40.397154,49.952553)
ehmedli=(40.385484,49.954108)
hazi_aslanov=(40.373495,49.953720)
xetai=(40.383371,49.871891)
nizami=(40.380551,49.831261)
elmler=(40.375498,49.815841)
insaatcilar=(40.391546,49.802592)
yanvar=(40.404285,49.807967)
memar_ecemi=(40.411426,49.814508)
cefer_cabbarli=(40.379905,49.849386)
nesimi=(40.424714,49.825177)
azadliq=(40.425395,49.841976)
dernegul=(40.425710,49.861958)
df_train["iceriseher"]= df_train.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.366131,49.831605)), axis=1)
df_test["iceriseher"]= df_test.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.366131,49.831605)), axis=1)
df_train["iceriseher"]= df_train.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.366131,49.831605)), axis=1)
df_test["iceriseher"]= df_test.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.366131,49.831605)), axis=1)
df_train["sahil"] =df_train.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.371309, 49.844516)), axis=1)
df_test["sahil"] = df_test.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.371309, 49.844516)), axis=1)
df_train["may"] =df_train.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.380087,49.848637)), axis=1)
df_test["may"] =df_test.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.380087,49.848637)), axis=1)
df_train["genclik"] =df_train.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.400640,49.851941)), axis=1)
df_test["genclik"] =df_test.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.400640,49.851941)), axis=1)
df_train["neriman_nerimanov"] =df_train.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.403156,49.870734)), axis=1)
df_test["neriman_nerimanov"] =df_test.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.403156,49.870734)), axis=1)
df_train["xetai"] =df_train.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.383371,49.871891)), axis=1)
df_test["xetai"] = df_test.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.383371,49.871891)), axis=1)
df_train["nizami"] = df_train.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.380551,49.831261)), axis=1)
df_test["nizami"] =df_test.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.380551,49.831261)), axis=1)
df_train["elmler"] = df_train.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.375498,49.815841)), axis=1)
df_test["elmler"] = df_test.apply(lambda row: h3.point_dist((row['latitude'], row['longitude']), (40.375498,49.815841)), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
def is_urgent(description):
    urg=["parkovka","parking","parkovkası","parkinqi","парковка","парковки"]
    
    for word in str(description).split():
        if word.lower() in urg:
            return 1
    for word in str(description).split('.'):
        if word.lower() in urg:
            return 1
    for word in str(description).split(','):
        if word.lower() in urg:
            return 1
    return 0
df_train['parkovka'] = df_train.apply(lambda row: is_urgent(row.description), axis=1)
df_test['parkovka'] = df_test.apply(lambda row: is_urgent(row.description), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pd.set_option('display.max_colwidth', 255)

# %%
df_train
# Out:
#           _id                                                     title  \
# 0           6           Satılır 3 otaqlı yeni tikili 135 m², Gənclik m.
# 1          22       Satılır 3 otaqlı yeni tikili 132.5 m², Nərimanov r.
# 2          72             Satılır 2 otaqlı yeni tikili 115 m², Bayıl q.
# 3          76            Satılır 2 otaqlı yeni tikili 43 m², Masazır q.
# 4          86        Satılır 2 otaqlı yeni tikili 65 m², Memar Əcəmi m.
# ...       ...                                                       ...
# 69310  147185            Satılır 4 otaqlı yeni tikili 220 m², Nəsimi r.
# 69311  147186  Satılır 2 otaqlı yeni tikili 68 m², Nəriman Nərimanov m.
# 69312  147187              Satılır 2 otaqlı yeni tikili 72 m², Xırdalan
# 69313  147189             Satılır 3 otaqlı yeni tikili 109 m², Xırdalan
# 69314  147190              Satılır 2 otaqlı yeni tikili 82 m², Xırdalan
#
#         price price_currency         poster       poster_type  \
# ...

# %%
#remove outliers

column='price'
q_low = df_train[column].quantile(0.01)
q_hi  = df_train[column].quantile(0.99)
df_train = df_train[(df_train[column] < q_hi) & (df_train[column] > q_low)]
df_train.shape
# Out:
# (67900, 34)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X = df_train[["Sahə","Otaq sayı","exact_mertebe","relative_mertebe","baki","sumqayit","xirdalan","longitude","latitude","is_urgent","metro","iceriseher","merkez","qaz","ucuz","temir","uni"]].values.reshape(-1,17)
y = df_train["price"].values

# scaler = StandardScaler()
# scaled_X = scaler.fit_transform(X)
# X = scaled_X
X_test_sub = df_test[["Sahə","Otaq sayı","exact_mertebe","relative_mertebe","baki","sumqayit","xirdalan","longitude","latitude","is_urgent","metro","iceriseher","merkez","qaz","ucuz","temir","uni"]].values.reshape(-1,17)
# scaled_X_sub = scaler.transform(X_test_sub)
# X_test_sub = scaled_X_sub


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


model_lr = LinearRegression()
model_lr_sub = LinearRegression()

model_lr.fit(X_train,y_train)
model_lr_sub.fit(X,y)


y_pred_lr = model_lr.predict(X_test)
y_pred_lr_sub = model_lr_sub.predict(X_test_sub)

mean_squared_error(y_test,y_pred_lr,squared=False)
# Out:
# 86105.29407846193

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

model_xgb = XGBRegressor(colsample_bytree =1,learning_rate = 0.1,max_depth=18,min_child_weight= 1,n_estimators=100,subsample=0.75)
model_xgb_sub = XGBRegressor(colsample_bytree =0.75,learning_rate = 0.05,max_depth=18,min_child_weight= 1,n_estimators=100,subsample=0.75)


model_xgb.fit(X_train, y_train,
              verbose=True)
model_xgb_sub.fit(X, y,verbose=True)

y_pred_xgb = model_xgb.predict(X_test)
y_pred_xgb_sub = model_xgb_sub.predict(X_test_sub)

rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
print(f'RMSE_xgb: {int(rmse_xgb)}')
y_pred_xgb
# Out:
# [22:38:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:38:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE_xgb: 39210
# array([495061.53, 215110.55, 184927.33, ..., 227656.83, 293961.2 ,
#        201267.17], dtype=float32)

# %%
df_sub=pd.DataFrame()
df_sub['_id']=df_test._id
df_sub['price']=pd.DataFrame(y_pred_xgb_sub)
df_sub.to_csv("azalda.csv",index=False)

# %%
pd.read_csv("azalda.csv")
# Out:
#           _id       price
# 0       20886   73611.680
# 1      117465  133340.280
# 2      125220  498398.200
# 3       77683  132785.170
# 4       77672  356284.940
# ...       ...         ...
# 19995  145960  138244.160
# 19996   66440  284989.660
# 19997   29047   92850.830
# 19998   81762  342234.440
# 19999  137332   87799.805
#
# [20000 rows x 2 columns]
